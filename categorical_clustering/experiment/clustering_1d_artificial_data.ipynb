# %%
import pandas as pd

from categorical_clustering.experiment.label_generator import generate_labels
labels = generate_labels({'A': 20, 'B': 10, 'C': 5, 'D': 15})
df = pd.DataFrame(data={'Labels': labels})

# %%
from categorical_clustering.core.algorithm.separate_attribute_pmf import SeparateAttributePMF as SAPMF
model = SAPMF(n_clusters=3)
model.set_data(df)

# %%
clustering, iters = model.perform_clustering(update_proportion_criterion=1e-2, verbose=True)
print('Converged in {} iterations!'.format(iters))
print('Clusters:')
model.clustering.clusters
# Out:
# Moved points in iteration 1: 50
# Overall impurity is now: 1.051125096418899
# Moved points in iteration 2: 50
# Overall impurity is now: 1.2798542258336676
# Moved points in iteration 3: 50
# Overall impurity is now: 1.051125096418899
# Moved points in iteration 4: 50
# Overall impurity is now: 1.2798542258336676
# Moved points in iteration 5: 50
# Overall impurity is now: 1.051125096418899
# Moved points in iteration 6: 50
# Overall impurity is now: 1.2798542258336676
# Moved points in iteration 7: 50
# Overall impurity is now: 1.051125096418899
# Moved points in iteration 8: 50
# /Users/hezardastan/Library/Python/3.7/lib/python/site-packages/scipy/stats/_distn_infrastructure.py:2544: RuntimeWarning: invalid value encountered in true_divide
#   pk = 1.0*pk / np.sum(pk, axis=0)
# Overall impurity is now: 1.2798542258336676
# Moved points in iteration 9: 50
# Overall impurity is now: 1.051125096418899
# Moved points in iteration 10: 50
# Overall impurity is now: 1.2798542258336676
# Moved points in iteration 11: 50
# Overall impurity is now: 1.051125096418899
# Moved points in iteration 12: 50
# Overall impurity is now: 1.2798542258336676
# Moved points in iteration 13: 50
# Overall impurity is now: 1.051125096418899
# Moved points in iteration 14: 50
# Overall impurity is now: 1.2798542258336676
# Moved points in iteration 15: 50
# Overall impurity is now: 1.051125096418899
# Moved points in iteration 16: 50
# Overall impurity is now: 1.2798542258336676
# Moved points in iteration 17: 50
# Overall impurity is now: 1.051125096418899
# Moved points in iteration 18: 50
# Overall impurity is now: 1.2798542258336676
# Moved points in iteration 19: 50
# Overall impurity is now: 1.051125096418899
# Moved points in iteration 20: 50
# Overall impurity is now: 1.2798542258336676
# Moved points in iteration 21: 50
# Overall impurity is now: 1.051125096418899
# Moved points in iteration 22: 50
# Overall impurity is now: 1.2798542258336676
# Moved points in iteration 23: 50
# Overall impurity is now: 1.051125096418899
# Moved points in iteration 24: 50
# Overall impurity is now: 1.2798542258336676
# Moved points in iteration 25: 50
# Overall impurity is now: 1.051125096418899
# Moved points in iteration 26: 50
# Overall impurity is now: 1.2798542258336676
# Moved points in iteration 27: 50
# Overall impurity is now: 1.051125096418899
# Moved points in iteration 28: 50
# Overall impurity is now: 1.2798542258336676
# Moved points in iteration 29: 50
# Overall impurity is now: 1.051125096418899
# Moved points in iteration 30: 50
# Overall impurity is now: 1.2798542258336676
# Moved points in iteration 31: 50
# Overall impurity is now: 1.051125096418899
# Moved points in iteration 32: 50
# Overall impurity is now: 1.2798542258336676
# Moved points in iteration 33: 50
# Overall impurity is now: 1.051125096418899
# Moved points in iteration 34: 50
# Overall impurity is now: 1.2798542258336676
# Moved points in iteration 35: 50
# Overall impurity is now: 1.051125096418899
# Moved points in iteration 36: 50
# Overall impurity is now: 1.2798542258336676
# Moved points in iteration 37: 50
# Overall impurity is now: 1.051125096418899
# Moved points in iteration 38: 50
# Overall impurity is now: 1.2798542258336676
# Moved points in iteration 39: 50
# Overall impurity is now: 1.051125096418899
# Moved points in iteration 40: 50
# Overall impurity is now: 1.2798542258336676
# Moved points in iteration 41: 50
# Overall impurity is now: 1.051125096418899
# Moved points in iteration 42: 50
# Overall impurity is now: 1.2798542258336676
# Moved points in iteration 43: 50
# Overall impurity is now: 1.051125096418899
# Moved points in iteration 44: 50
# Overall impurity is now: 1.2798542258336676
# Moved points in iteration 45: 50
# Overall impurity is now: 1.051125096418899
# Moved points in iteration 46: 50
# Overall impurity is now: 1.2798542258336676
# Moved points in iteration 47: 50
# Overall impurity is now: 1.051125096418899
# Moved points in iteration 48: 50
# Overall impurity is now: 1.2798542258336676
# Moved points in iteration 49: 50
# Overall impurity is now: 1.051125096418899
# Moved points in iteration 50: 50
# Overall impurity is now: 1.2798542258336676
# Moved points in iteration 51: 50
# Overall impurity is now: 1.051125096418899
# Moved points in iteration 52: 50
# Overall impurity is now: 1.2798542258336676
# Moved points in iteration 53: 50
# Overall impurity is now: 1.051125096418899
# Moved points in iteration 54: 50
# Overall impurity is now: 1.2798542258336676
# Moved points in iteration 55: 50
# Overall impurity is now: 1.051125096418899
# Moved points in iteration 56: 50
# Overall impurity is now: 1.2798542258336676
# Moved points in iteration 57: 50
# Overall impurity is now: 1.051125096418899
# Moved points in iteration 58: 50
# Overall impurity is now: 1.2798542258336676
# Moved points in iteration 59: 50
# Overall impurity is now: 1.051125096418899
# Moved points in iteration 60: 50
# Overall impurity is now: 1.2798542258336676
# Moved points in iteration 61: 50
# Overall impurity is now: 1.051125096418899
# Moved points in iteration 62: 50
# Overall impurity is now: 1.2798542258336676
# Moved points in iteration 63: 50
# Overall impurity is now: 1.051125096418899
# Moved points in iteration 64: 50
# Overall impurity is now: 1.2798542258336676
# Moved points in iteration 65: 50
# Overall impurity is now: 1.051125096418899
# Moved points in iteration 66: 50
# Overall impurity is now: 1.2798542258336676
# Moved points in iteration 67: 50
# Overall impurity is now: 1.051125096418899
# Moved points in iteration 68: 50
# Overall impurity is now: 1.2798542258336676
# Moved points in iteration 69: 50
# Overall impurity is now: 1.051125096418899
# Moved points in iteration 70: 50
# Overall impurity is now: 1.2798542258336676
# Moved points in iteration 71: 50
# Overall impurity is now: 1.051125096418899
# Moved points in iteration 72: 50
# Overall impurity is now: 1.2798542258336676
# Moved points in iteration 73: 50
# Overall impurity is now: 1.051125096418899
# Moved points in iteration 74: 50
# Overall impurity is now: 1.2798542258336676
# Moved points in iteration 75: 50
# Overall impurity is now: 1.051125096418899
# Moved points in iteration 76: 50
# Overall impurity is now: 1.2798542258336676
# Moved points in iteration 77: 50
# Overall impurity is now: 1.051125096418899
# Moved points in iteration 78: 50
# Overall impurity is now: 1.2798542258336676
# Moved points in iteration 79: 50
# Overall impurity is now: 1.051125096418899
# Moved points in iteration 80: 50
# Overall impurity is now: 1.2798542258336676
# Moved points in iteration 81: 50
# Overall impurity is now: 1.051125096418899
# Moved points in iteration 82: 50
# Overall impurity is now: 1.2798542258336676
# Moved points in iteration 83: 50
# Overall impurity is now: 1.051125096418899
# Moved points in iteration 84: 50
# Overall impurity is now: 1.2798542258336676
# Moved points in iteration 85: 50
# Overall impurity is now: 1.051125096418899
# Moved points in iteration 86: 50
# Overall impurity is now: 1.2798542258336676
# Moved points in iteration 87: 50
# Overall impurity is now: 1.051125096418899
# Moved points in iteration 88: 50
# Overall impurity is now: 1.2798542258336676
# Moved points in iteration 89: 50
# Overall impurity is now: 1.051125096418899
# Moved points in iteration 90: 50
# Overall impurity is now: 1.2798542258336676
# Moved points in iteration 91: 50
# Overall impurity is now: 1.051125096418899
# Moved points in iteration 92: 50
# Overall impurity is now: 1.2798542258336676
# Moved points in iteration 93: 50
# Overall impurity is now: 1.051125096418899
# Moved points in iteration 94: 50
# Overall impurity is now: 1.2798542258336676
# Moved points in iteration 95: 50
# Overall impurity is now: 1.051125096418899
# Moved points in iteration 96: 50
# Overall impurity is now: 1.2798542258336676
# Moved points in iteration 97: 50
# Overall impurity is now: 1.051125096418899
# Moved points in iteration 98: 50
# Overall impurity is now: 1.2798542258336676
# Moved points in iteration 99: 50
# Overall impurity is now: 1.051125096418899
# Moved points in iteration 100: 50
# Overall impurity is now: 1.2798542258336676
# Moved points in iteration 101: 50
# Overall impurity is now: 1.051125096418899
# Moved points in iteration 102: 50
# Overall impurity is now: 1.2798542258336676
# Moved points in iteration 103: 50
# Overall impurity is now: 1.051125096418899
# Moved points in iteration 104: 50
# Overall impurity is now: 1.2798542258336676
# Moved points in iteration 105: 50
# Overall impurity is now: 1.051125096418899
# Moved points in iteration 106: 50
# Overall impurity is now: 1.2798542258336676
# Moved points in iteration 107: 50
# Overall impurity is now: 1.051125096418899
# Moved points in iteration 108: 50
# Overall impurity is now: 1.2798542258336676
# Moved points in iteration 109: 50
# Overall impurity is now: 1.051125096418899
# Moved points in iteration 110: 50
# Overall impurity is now: 1.2798542258336676
# Moved points in iteration 111: 50
# Overall impurity is now: 1.051125096418899
# Moved points in iteration 112: 50
# Overall impurity is now: 1.2798542258336676
# Moved points in iteration 113: 50
# Overall impurity is now: 1.051125096418899
# Moved points in iteration 114: 50
# Overall impurity is now: 1.2798542258336676
# Moved points in iteration 115: 50
# Overall impurity is now: 1.051125096418899
# Moved points in iteration 116: 50
# Overall impurity is now: 1.2798542258336676
# Moved points in iteration 117: 50
# Overall impurity is now: 1.051125096418899
# Moved points in iteration 118: 50
# Overall impurity is now: 1.2798542258336676
# Moved points in iteration 119: 50
# Overall impurity is now: 1.051125096418899
# Moved points in iteration 120: 50
# Overall impurity is now: 1.2798542258336676
# Moved points in iteration 121: 50
# Overall impurity is now: 1.051125096418899
# Moved points in iteration 122: 50
# Overall impurity is now: 1.2798542258336676
# Moved points in iteration 123: 50
# Overall impurity is now: 1.051125096418899
# Moved points in iteration 124: 50
# Overall impurity is now: 1.2798542258336676
# Moved points in iteration 125: 50
# Overall impurity is now: 1.051125096418899
# Moved points in iteration 126: 50
# Overall impurity is now: 1.2798542258336676
# Moved points in iteration 127: 50
# Overall impurity is now: 1.051125096418899
# Moved points in iteration 128: 50
# Overall impurity is now: 1.2798542258336676
# Moved points in iteration 129: 50
# Overall impurity is now: 1.051125096418899
# Moved points in iteration 130: 50
# Overall impurity is now: 1.2798542258336676
# Moved points in iteration 131: 50
# Overall impurity is now: 1.051125096418899
# Moved points in iteration 132: 50
# Overall impurity is now: 1.2798542258336676
# Moved points in iteration 133: 50
# Overall impurity is now: 1.051125096418899
# Moved points in iteration 134: 50
# Overall impurity is now: 1.2798542258336676
# Moved points in iteration 135: 50
# Overall impurity is now: 1.051125096418899
# Moved points in iteration 136: 50
# Overall impurity is now: 1.2798542258336676
# Moved points in iteration 137: 50
# Overall impurity is now: 1.051125096418899
# Moved points in iteration 138: 50
# Overall impurity is now: 1.2798542258336676
# Moved points in iteration 139: 50
# Overall impurity is now: 1.051125096418899
# Moved points in iteration 140: 50
# Overall impurity is now: 1.2798542258336676
# Moved points in iteration 141: 50
# Overall impurity is now: 1.051125096418899
# Moved points in iteration 142: 50
# Overall impurity is now: 1.2798542258336676
# Moved points in iteration 143: 50
# Overall impurity is now: 1.051125096418899
# Moved points in iteration 144: 50
# Overall impurity is now: 1.2798542258336676
# Moved points in iteration 145: 50
# Overall impurity is now: 1.051125096418899
# Moved points in iteration 146: 50
# Overall impurity is now: 1.2798542258336676
# Moved points in iteration 147: 50
# Overall impurity is now: 1.051125096418899
# Moved points in iteration 148: 50
# Overall impurity is now: 1.2798542258336676
# Moved points in iteration 149: 50
# Overall impurity is now: 1.051125096418899
# Moved points in iteration 150: 50
# Overall impurity is now: 1.2798542258336676
# Moved points in iteration 151: 50
# Overall impurity is now: 1.051125096418899
# Moved points in iteration 152: 50
# Overall impurity is now: 1.2798542258336676
# Moved points in iteration 153: 50
# Overall impurity is now: 1.051125096418899
# Moved points in iteration 154: 50
# Overall impurity is now: 1.2798542258336676
# Moved points in iteration 155: 50
# Overall impurity is now: 1.051125096418899
# Moved points in iteration 156: 50
# Overall impurity is now: 1.2798542258336676
# Moved points in iteration 157: 50
# Overall impurity is now: 1.051125096418899
# Moved points in iteration 158: 50
# Overall impurity is now: 1.2798542258336676
# Moved points in iteration 159: 50
# Overall impurity is now: 1.051125096418899
# Moved points in iteration 160: 50
# Overall impurity is now: 1.2798542258336676
# Moved points in iteration 161: 50
# Overall impurity is now: 1.051125096418899
# Moved points in iteration 162: 50
# Overall impurity is now: 1.2798542258336676
# Moved points in iteration 163: 50
# Overall impurity is now: 1.051125096418899
# Moved points in iteration 164: 50
# Overall impurity is now: 1.2798542258336676
# Moved points in iteration 165: 50
# Overall impurity is now: 1.051125096418899
# Moved points in iteration 166: 50
# Overall impurity is now: 1.2798542258336676
# Moved points in iteration 167: 50
# Overall impurity is now: 1.051125096418899
# Moved points in iteration 168: 50
# Overall impurity is now: 1.2798542258336676
# Moved points in iteration 169: 50
# Overall impurity is now: 1.051125096418899
# Moved points in iteration 170: 50
# Overall impurity is now: 1.2798542258336676
# Moved points in iteration 171: 50
# Overall impurity is now: 1.051125096418899
# Moved points in iteration 172: 50
# Overall impurity is now: 1.2798542258336676
# Moved points in iteration 173: 50
# Overall impurity is now: 1.051125096418899
# Moved points in iteration 174: 50
# Overall impurity is now: 1.2798542258336676
# Moved points in iteration 175: 50
# Overall impurity is now: 1.051125096418899
# Moved points in iteration 176: 50
# Overall impurity is now: 1.2798542258336676
# Moved points in iteration 177: 50
# Overall impurity is now: 1.051125096418899
# Moved points in iteration 178: 50
# Overall impurity is now: 1.2798542258336676
# Moved points in iteration 179: 50
# Overall impurity is now: 1.051125096418899
# Moved points in iteration 180: 50
# Overall impurity is now: 1.2798542258336676
# Moved points in iteration 181: 50
# Overall impurity is now: 1.051125096418899
# Moved points in iteration 182: 50
# Overall impurity is now: 1.2798542258336676
# Moved points in iteration 183: 50
# Overall impurity is now: 1.051125096418899
# Moved points in iteration 184: 50
# Overall impurity is now: 1.2798542258336676
# Moved points in iteration 185: 50
# Overall impurity is now: 1.051125096418899
# Moved points in iteration 186: 50
# Overall impurity is now: 1.2798542258336676
# Moved points in iteration 187: 50
# Overall impurity is now: 1.051125096418899
# Moved points in iteration 188: 50
# Overall impurity is now: 1.2798542258336676
# Moved points in iteration 189: 50
# Overall impurity is now: 1.051125096418899
# Moved points in iteration 190: 50
# Overall impurity is now: 1.2798542258336676
# Moved points in iteration 191: 50
# Overall impurity is now: 1.051125096418899
# Moved points in iteration 192: 50
# Overall impurity is now: 1.2798542258336676
# Moved points in iteration 193: 50
# Overall impurity is now: 1.051125096418899
# Moved points in iteration 194: 50
# Overall impurity is now: 1.2798542258336676
# Moved points in iteration 195: 50
# Overall impurity is now: 1.051125096418899
# Moved points in iteration 196: 50
# Overall impurity is now: 1.2798542258336676
# Moved points in iteration 197: 50
# Overall impurity is now: 1.051125096418899
# Moved points in iteration 198: 50
# Overall impurity is now: 1.2798542258336676
# Moved points in iteration 199: 50
# Overall impurity is now: 1.051125096418899
# Moved points in iteration 200: 50
# Overall impurity is now: 1.2798542258336676
# Moved points in iteration 201: 50
# Overall impurity is now: 1.051125096418899
# Moved points in iteration 202: 50
# Overall impurity is now: 1.2798542258336676
# Moved points in iteration 203: 50
# Overall impurity is now: 1.051125096418899
# Moved points in iteration 204: 50
# Overall impurity is now: 1.2798542258336676
# Moved points in iteration 205: 50
# Overall impurity is now: 1.051125096418899
# Moved points in iteration 206: 50
# Overall impurity is now: 1.2798542258336676
# Moved points in iteration 207: 50
# Overall impurity is now: 1.051125096418899
# Moved points in iteration 208: 50
# Overall impurity is now: 1.2798542258336676
# Moved points in iteration 209: 50
# Overall impurity is now: 1.051125096418899
# Moved points in iteration 210: 50
# Overall impurity is now: 1.2798542258336676
# Moved points in iteration 211: 50
# Overall impurity is now: 1.051125096418899
# Moved points in iteration 212: 50
# Overall impurity is now: 1.2798542258336676
# Moved points in iteration 213: 50
# Overall impurity is now: 1.051125096418899
# Moved points in iteration 214: 50
# Overall impurity is now: 1.2798542258336676
# Moved points in iteration 215: 50
# Overall impurity is now: 1.051125096418899
# Moved points in iteration 216: 50
# Overall impurity is now: 1.2798542258336676
# Moved points in iteration 217: 50
# Overall impurity is now: 1.051125096418899
# Moved points in iteration 218: 50
# Overall impurity is now: 1.2798542258336676
# Moved points in iteration 219: 50
# Overall impurity is now: 1.051125096418899
# Moved points in iteration 220: 50
# Overall impurity is now: 1.2798542258336676
# Moved points in iteration 221: 50
# Overall impurity is now: 1.051125096418899
# Moved points in iteration 222: 50
# Overall impurity is now: 1.2798542258336676
# Moved points in iteration 223: 50
# Overall impurity is now: 1.051125096418899
# Moved points in iteration 224: 50
# Overall impurity is now: 1.2798542258336676
# Moved points in iteration 225: 50
# Overall impurity is now: 1.051125096418899
# Moved points in iteration 226: 50
# Overall impurity is now: 1.2798542258336676
# Moved points in iteration 227: 50
# Overall impurity is now: 1.051125096418899
# Moved points in iteration 228: 50
# Overall impurity is now: 1.2798542258336676
# Moved points in iteration 229: 50
# Overall impurity is now: 1.051125096418899
# Moved points in iteration 230: 50
# Overall impurity is now: 1.2798542258336676
# Moved points in iteration 231: 50
# Overall impurity is now: 1.051125096418899
# Moved points in iteration 232: 50
# Overall impurity is now: 1.2798542258336676
# Moved points in iteration 233: 50
# Overall impurity is now: 1.051125096418899
# Moved points in iteration 234: 50
# Overall impurity is now: 1.2798542258336676
# Moved points in iteration 235: 50
# Overall impurity is now: 1.051125096418899
# Moved points in iteration 236: 50
# Overall impurity is now: 1.2798542258336676
# Moved points in iteration 237: 50
# Overall impurity is now: 1.051125096418899
# Moved points in iteration 238: 50
# Overall impurity is now: 1.2798542258336676
# Moved points in iteration 239: 50
# Overall impurity is now: 1.051125096418899
# Moved points in iteration 240: 50
# Overall impurity is now: 1.2798542258336676
# Moved points in iteration 241: 50
# Overall impurity is now: 1.051125096418899
# Moved points in iteration 242: 50
# Overall impurity is now: 1.2798542258336676
# Moved points in iteration 243: 50
# Overall impurity is now: 1.051125096418899
# Moved points in iteration 244: 50
# Overall impurity is now: 1.2798542258336676
# Moved points in iteration 245: 50
# Overall impurity is now: 1.051125096418899
# Moved points in iteration 246: 50
# Overall impurity is now: 1.2798542258336676
# Moved points in iteration 247: 50
# Overall impurity is now: 1.051125096418899
# Moved points in iteration 248: 50
# Overall impurity is now: 1.2798542258336676
# Moved points in iteration 249: 50
# Overall impurity is now: 1.051125096418899
# Moved points in iteration 250: 50
# Overall impurity is now: 1.2798542258336676
# Moved points in iteration 251: 50
# Overall impurity is now: 1.051125096418899
# Moved points in iteration 252: 50
# Overall impurity is now: 1.2798542258336676
# Moved points in iteration 253: 50
# Overall impurity is now: 1.051125096418899
# Moved points in iteration 254: 50
# Overall impurity is now: 1.2798542258336676
# Moved points in iteration 255: 50
# Overall impurity is now: 1.051125096418899
# Moved points in iteration 256: 50
# Overall impurity is now: 1.2798542258336676
# Moved points in iteration 257: 50
# Overall impurity is now: 1.051125096418899
# Moved points in iteration 258: 50
# Overall impurity is now: 1.2798542258336676
# Moved points in iteration 259: 50
# Overall impurity is now: 1.051125096418899
# Moved points in iteration 260: 50
# Overall impurity is now: 1.2798542258336676
# Moved points in iteration 261: 50
# Overall impurity is now: 1.051125096418899
# Moved points in iteration 262: 50
# Overall impurity is now: 1.2798542258336676
# Moved points in iteration 263: 50
# Overall impurity is now: 1.051125096418899
# Moved points in iteration 264: 50
# Overall impurity is now: 1.2798542258336676
# Moved points in iteration 265: 50
# Overall impurity is now: 1.051125096418899
# Moved points in iteration 266: 50
# Overall impurity is now: 1.2798542258336676
# Moved points in iteration 267: 50
# Overall impurity is now: 1.051125096418899
# Moved points in iteration 268: 50
# Overall impurity is now: 1.2798542258336676
# Moved points in iteration 269: 50
# Overall impurity is now: 1.051125096418899
# Moved points in iteration 270: 50
# Overall impurity is now: 1.2798542258336676
# Moved points in iteration 271: 50
# Overall impurity is now: 1.051125096418899
# Moved points in iteration 272: 50
# Overall impurity is now: 1.2798542258336676
# Moved points in iteration 273: 50
# Overall impurity is now: 1.051125096418899
# Moved points in iteration 274: 50
# Overall impurity is now: 1.2798542258336676
# Moved points in iteration 275: 50
# Overall impurity is now: 1.051125096418899
# Moved points in iteration 276: 50
# Overall impurity is now: 1.2798542258336676
# Moved points in iteration 277: 50
# Overall impurity is now: 1.051125096418899
# Moved points in iteration 278: 50
# Overall impurity is now: 1.2798542258336676
# Moved points in iteration 279: 50
# Overall impurity is now: 1.051125096418899
# Moved points in iteration 280: 50
# Overall impurity is now: 1.2798542258336676
# Moved points in iteration 281: 50
# Overall impurity is now: 1.051125096418899
# Moved points in iteration 282: 50
# Overall impurity is now: 1.2798542258336676
# Moved points in iteration 283: 50
# Overall impurity is now: 1.051125096418899
# Moved points in iteration 284: 50
# Overall impurity is now: 1.2798542258336676
# Moved points in iteration 285: 50
# Overall impurity is now: 1.051125096418899
# Moved points in iteration 286: 50
# Overall impurity is now: 1.2798542258336676
# Moved points in iteration 287: 50
# Overall impurity is now: 1.051125096418899
# Moved points in iteration 288: 50
# Overall impurity is now: 1.2798542258336676
# Moved points in iteration 289: 50
# Overall impurity is now: 1.051125096418899
# Moved points in iteration 290: 50
# Overall impurity is now: 1.2798542258336676
# Moved points in iteration 291: 50
# Overall impurity is now: 1.051125096418899
# Moved points in iteration 292: 50
# Overall impurity is now: 1.2798542258336676
# Moved points in iteration 293: 50
# Overall impurity is now: 1.051125096418899
# Moved points in iteration 294: 50
# Overall impurity is now: 1.2798542258336676
# Moved points in iteration 295: 50
# Overall impurity is now: 1.051125096418899
# Moved points in iteration 296: 50
# Overall impurity is now: 1.2798542258336676
# Moved points in iteration 297: 50
# Overall impurity is now: 1.051125096418899
# Moved points in iteration 298: 50
# Overall impurity is now: 1.2798542258336676
# Moved points in iteration 299: 50
# Overall impurity is now: 1.051125096418899
# Moved points in iteration 300: 50
# Overall impurity is now: 1.2798542258336676
# Moved points in iteration 301: 50
# Overall impurity is now: 1.051125096418899
# Moved points in iteration 302: 50
# Overall impurity is now: 1.2798542258336676
# Moved points in iteration 303: 50
# Overall impurity is now: 1.051125096418899
# Moved points in iteration 304: 50
# Overall impurity is now: 1.2798542258336676
# Moved points in iteration 305: 50
# Overall impurity is now: 1.051125096418899
# Moved points in iteration 306: 50
# Overall impurity is now: 1.2798542258336676
# Moved points in iteration 307: 50
# Overall impurity is now: 1.051125096418899
# Moved points in iteration 308: 50
# Overall impurity is now: 1.2798542258336676
# Moved points in iteration 309: 50
# Overall impurity is now: 1.051125096418899
# Moved points in iteration 310: 50
# Overall impurity is now: 1.2798542258336676
# Moved points in iteration 311: 50
# Overall impurity is now: 1.051125096418899
# Moved points in iteration 312: 50
# Overall impurity is now: 1.2798542258336676
# Moved points in iteration 313: 50
# Overall impurity is now: 1.051125096418899
# Moved points in iteration 314: 50
# Overall impurity is now: 1.2798542258336676
# Moved points in iteration 315: 50
# Overall impurity is now: 1.051125096418899
# Moved points in iteration 316: 50
# Overall impurity is now: 1.2798542258336676
# Moved points in iteration 317: 50
# Overall impurity is now: 1.051125096418899
# Moved points in iteration 318: 50
# Overall impurity is now: 1.2798542258336676
# Moved points in iteration 319: 50
# Overall impurity is now: 1.051125096418899
# Moved points in iteration 320: 50
# Overall impurity is now: 1.2798542258336676
# Moved points in iteration 321: 50
# Overall impurity is now: 1.051125096418899
# Moved points in iteration 322: 50
# Overall impurity is now: 1.2798542258336676
# Moved points in iteration 323: 50
# Overall impurity is now: 1.051125096418899
# Moved points in iteration 324: 50
# Overall impurity is now: 1.2798542258336676
# Moved points in iteration 325: 50
# Overall impurity is now: 1.051125096418899
# Moved points in iteration 326: 50
# Overall impurity is now: 1.2798542258336676
# Moved points in iteration 327: 50
# Overall impurity is now: 1.051125096418899
# Moved points in iteration 328: 50
# Overall impurity is now: 1.2798542258336676
# Moved points in iteration 329: 50
# Overall impurity is now: 1.051125096418899
# Moved points in iteration 330: 50
# Overall impurity is now: 1.2798542258336676
# Moved points in iteration 331: 50
# Overall impurity is now: 1.051125096418899
# Moved points in iteration 332: 50
# Overall impurity is now: 1.2798542258336676
# Moved points in iteration 333: 50
# Overall impurity is now: 1.051125096418899
# Moved points in iteration 334: 50
# Overall impurity is now: 1.2798542258336676
# Moved points in iteration 335: 50
# Overall impurity is now: 1.051125096418899
# Moved points in iteration 336: 50
# Overall impurity is now: 1.2798542258336676
# Moved points in iteration 337: 50
# Overall impurity is now: 1.051125096418899
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-004dc9a62cf4> in <module>
# ----> 1 clustering, iters = model.perform_clustering(update_proportion_criterion=1e-2, verbose=True)
#       2 print('Converged in {} iterations!'.format(iters))
#       3 print('Clusters:')
#       4 model.clustering.clusters
#
# ~/Projects/MachineLearning/CategoricalClustering/categorical_clustering/core/algorithm/base.py in perform_clustering(self, update_proportion_criterion, verbose)
#      88             iterations += 1
#      89             centroids = self._calculate_centroids()
# ---> 90             moved_points_count = self._assign_data_to_clusters(centroids)
#      91             if verbose:
#      92                 print('Moved points in iteration {}: {}'.format(iterations, moved_points_count))
#
# ~/Projects/MachineLearning/CategoricalClustering/categorical_clustering/core/algorithm/separate_attribute_pmf.py in _assign_data_to_clusters(self, centroids)
#      41
#      42             if prev_cluster != selected_cluster:
# ---> 43                 tmp = self.clustering.clusters[prev_cluster][multi_index]
#      44                 self.clustering.clusters[prev_cluster][multi_index] = tmp - 1
#      45                 tmp = self.clustering.clusters[selected_cluster][multi_index]
#
# KeyboardInterrupt:

# %%
import chart_studio.plotly as py
import plotly.graph_objects as go

df = model.get_cluster_as_dataframe(cluster=-1)

fig = go.Figure(data=[
    go.Bar(x=df.index, y=df.iloc[:, 0])
])
fig.update_xaxes(title='Labels')
fig.update_yaxes(title='Counts')
fig.update_layout(title='Overall Data', autosize=False, width=500, height=400)
fig.show()

# %%
from categorical_clustering.core.algorithm.separate_attribute_pmf import SeparateAttributePMF as SAPMF
model = SAPMF(n_clusters=3)
model.set_data(df)

# %%
centroids = model._calculate_centroids()
centroids

# %%
model._assign_data_to_clusters(centroids)
model.clustering.clusters

# %%
centroids = model._calculate_centroids()
centroids

# %%
model._assign_data_to_clusters(centroids)
model.clustering.clusters

# %%
df = model.get_cluster_as_dataframe(cluster=0)

fig = go.Figure(data=[
    go.Bar(x=df.index, y=df.iloc[:, 0])
])
fig.update_xaxes(title='Labels')
fig.update_yaxes(title='Counts')
fig.update_layout(title='Cluster 0', autosize=False, width=500, height=400)
fig.show()

df = model.get_cluster_as_dataframe(cluster=1)

fig = go.Figure(data=[
    go.Bar(x=df.index, y=df.iloc[:, 0])
])
fig.update_xaxes(title='Labels')
fig.update_yaxes(title='Counts')
fig.update_layout(title='Cluster 1', autosize=False, width=500, height=400)
fig.show()

df = model.get_cluster_as_dataframe(cluster=2)

fig = go.Figure(data=[
    go.Bar(x=df.index, y=df.iloc[:, 0])
])
fig.update_xaxes(title='Labels')
fig.update_yaxes(title='Counts')
fig.update_layout(title='Cluster 2', autosize=False, width=500, height=400)
fig.show()
